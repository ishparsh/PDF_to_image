# %%
import os
from pdf2image import convert_from_path 
path="D:/bottle_flask/citizen/"    #  <--- change path here
filenames = next(os.walk(path))[2]
for f in filenames:
    #print(path)
    images = convert_from_path(path+f,poppler_path='C:/poppler-0.68.0/bin')
    name=(str(f).replace(".pdf", ""))
    for i in range(len(images)):
   
        # Save pages as images in the pdf
        images[i].save( name+str(i)+'.jpg', 'JPEG')

# %%
# !pip install python-poppler
# Out:
# ...
#   Using cached python-poppler-0.2.2.tar.gz (595 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for python-poppler
# Failed to build python-poppler
# ...
#     Running setup.py install for python-poppler: started
#     Running setup.py install for python-poppler: finished with status 'error'
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
# ...
